# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler,PowerTransformer
from sklearn.decomposition import PCA
from sklearn.mixture import BayesianGaussianMixture,GaussianMixture
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import metrics
import lightgbm as lgb
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from sklearn import metrics
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
df=pd.read_csv("th1.csv")
df
# Out:
#             Day       1       2       3       4       5       6       7  \
# 0      1/1/2021   964.4   964.4   964.4   964.4   964.4   964.4   964.4
# 1      1/2/2021  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7
# 2      1/3/2021   988.4   988.4   988.4   988.4   988.4   988.4   988.4
# 3      1/4/2021  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0
# 4      1/5/2021  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 360  27/12/2021  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0
# 361  28/12/2021  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0
# 362  29/12/2021  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
# 363  30/12/2021  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6
# 364  31/12/2021  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6
#
#           8       9  ...      39      40      41      42      43      44  \
# 0     964.4   964.4  ...   964.4   964.4   964.4   964.4   964.4   964.4
# 1    1019.7  1019.7  ...  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7
# 2     988.4   988.4  ...   988.4   988.4   988.4   988.4   988.4   988.4
# 3    1002.0  1002.1  ...  1010.8  1010.8  1010.8  1010.8  1010.8  1010.8
# 4    1061.5  1061.5  ...  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 360  1002.0  1002.0  ...  1002.1  1002.1  1002.1  1002.1  1002.1  1002.1
# 361  1002.0  1002.0  ...  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0
# 362  1061.5  1061.5  ...  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
# 363  1022.6  1022.6  ...  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6
# 364  1022.6  1022.6  ...  1022.6  1022.6  1022.6  1022.6  1022.6  1022.6
#
#          45      46      47      48
# 0     964.4   964.4   964.4   964.4
# 1    1019.7  1019.7  1019.7  1019.7
# 2     988.4   988.4   988.4   988.4
# 3    1010.8  1010.8  1010.8  1010.8
# 4    1061.5  1061.5  1061.5  1061.5
# ..      ...     ...     ...     ...
# 360  1002.1  1002.1  1002.0  1002.0
# 361  1002.0  1002.0  1002.0  1002.0
# 362  1061.5  1061.5  1061.5  1061.5
# 363  1022.6  1022.6  1022.6  1022.6
# 364  1022.6  1022.6  1022.6  1022.6
#
# [365 rows x 49 columns]

# %%
feats= ['11']

# %%
from sklearn.preprocessing import StandardScaler
transformer = StandardScaler()
X=transformer.fit_transform(np.array(df[feats]).reshape(-1,1))

# %%
BGM = BayesianGaussianMixture(n_components=7,covariance_type='full',random_state=1,n_init=15)
# fit model and predict clusters
preds = BGM.fit_predict(X)
df["Clusters"]= preds

# %%
pp=BGM.predict_proba(X)# Calcualting the probabilities of each prediction
df_new=pd.DataFrame(X,columns=feats)
df_new[[f'predict_proba_{i}' for i in range(7)]]=pp # creating new dataframe columns of probabilites
df_new['preds']=preds
df_new['predict_proba']=np.max(pp,axis=1)
df_new['predict']=np.argmax(pp,axis=1)

train_index=np.array([])
for n in range(7):
    n_inx=df_new[(df_new.preds==n) & (df_new.predict_proba > 0.68)].index
    train_index = np.concatenate((train_index, n_inx))

# %%
#ricopue's notebook's code snippet
from sklearn.model_selection import StratifiedKFold
X_new=df_new.loc[train_index][feats]
y=df_new.loc[train_index]['preds']

params_lgb = {'learning_rate': 0.06,'objective': 'multiclass','boosting': 'gbdt','n_jobs': -1,'verbosity': -1, 'num_classes':7}

model_list=[]

gkf = StratifiedKFold(11)
for fold, (train_idx, valid_idx) in enumerate(gkf.split(X_new,y)):

    tr_dataset = lgb.Dataset(X_new.iloc[train_idx],y.iloc[train_idx],feature_name = feats)
    vl_dataset = lgb.Dataset(X_new.iloc[valid_idx],y.iloc[valid_idx],feature_name = feats)

    model = lgb.train(params = params_lgb,
                train_set = tr_dataset,
                valid_sets =  vl_dataset,
                num_boost_round = 5000,
                callbacks=[ lgb.early_stopping(stopping_rounds=300, verbose=False), lgb.log_evaluation(period=200)])

    model_list.append(model)
# Out:
# [200]	valid_0's multi_logloss: 0.000291562
# [200]	valid_0's multi_logloss: 0.000291119
# [200]	valid_0's multi_logloss: 0.00026959
# [200]	valid_0's multi_logloss: 0.0127449
# [200]	valid_0's multi_logloss: 0.000164035
# [400]	valid_0's multi_logloss: 0.000162874
# [600]	valid_0's multi_logloss: 0.000162571
# [800]	valid_0's multi_logloss: 0.000162431
# [1000]	valid_0's multi_logloss: 0.000162351
# [1200]	valid_0's multi_logloss: 0.0001623
# [1400]	valid_0's multi_logloss: 0.000162265
# [1600]	valid_0's multi_logloss: 0.000162239
# [1800]	valid_0's multi_logloss: 0.000162219
# [2000]	valid_0's multi_logloss: 0.000162203
# [2200]	valid_0's multi_logloss: 0.00016219
# [2400]	valid_0's multi_logloss: 0.00016218
# [2600]	valid_0's multi_logloss: 0.000162171
# [2800]	valid_0's multi_logloss: 0.000162163
# [3000]	valid_0's multi_logloss: 0.000162157
# [3200]	valid_0's multi_logloss: 0.000162151
# [3400]	valid_0's multi_logloss: 0.000162147
# [3600]	valid_0's multi_logloss: 0.000162142
# [3800]	valid_0's multi_logloss: 0.000162138
# [4000]	valid_0's multi_logloss: 0.000162135
# [4200]	valid_0's multi_logloss: 0.000162132
# [4400]	valid_0's multi_logloss: 0.000162129
# [4600]	valid_0's multi_logloss: 0.000162126
# [4800]	valid_0's multi_logloss: 0.000162124
# [5000]	valid_0's multi_logloss: 0.000162122
# [200]	valid_0's multi_logloss: 0.000165746
# [400]	valid_0's multi_logloss: 0.000164396
# [600]	valid_0's multi_logloss: 0.000164025
# [800]	valid_0's multi_logloss: 0.000163852
# [1000]	valid_0's multi_logloss: 0.000163753
# [1200]	valid_0's multi_logloss: 0.000163689
# [1400]	valid_0's multi_logloss: 0.000163645
# [1600]	valid_0's multi_logloss: 0.000163612
# [1800]	valid_0's multi_logloss: 0.000163587
# [2000]	valid_0's multi_logloss: 0.000163567
# [2200]	valid_0's multi_logloss: 0.000163551
# [2400]	valid_0's multi_logloss: 0.000163538
# [2600]	valid_0's multi_logloss: 0.000163527
# [2800]	valid_0's multi_logloss: 0.000163517
# [3000]	valid_0's multi_logloss: 0.000163509
# [3200]	valid_0's multi_logloss: 0.000163502
# [3400]	valid_0's multi_logloss: 0.000163496
# [3600]	valid_0's multi_logloss: 0.000163491
# [3800]	valid_0's multi_logloss: 0.000163486
# [4000]	valid_0's multi_logloss: 0.000163481
# [4200]	valid_0's multi_logloss: 0.000163477
# [4400]	valid_0's multi_logloss: 0.000163474
# [4600]	valid_0's multi_logloss: 0.00016347
# [4800]	valid_0's multi_logloss: 0.000163467
# [5000]	valid_0's multi_logloss: 0.000163465
# [200]	valid_0's multi_logloss: 1.27314e-05
# [400]	valid_0's multi_logloss: 1.21332e-05
# [600]	valid_0's multi_logloss: 1.19955e-05
# [800]	valid_0's multi_logloss: 1.19246e-05
# [1000]	valid_0's multi_logloss: 1.18808e-05
# [1200]	valid_0's multi_logloss: 1.18521e-05
# [1400]	valid_0's multi_logloss: 1.18318e-05
# [1600]	valid_0's multi_logloss: 1.18168e-05
# [1800]	valid_0's multi_logloss: 1.18053e-05
# [2000]	valid_0's multi_logloss: 1.17961e-05
# [2200]	valid_0's multi_logloss: 1.17887e-05
# [2400]	valid_0's multi_logloss: 1.17825e-05
# [2600]	valid_0's multi_logloss: 1.17773e-05
# [2800]	valid_0's multi_logloss: 1.17729e-05
# [3000]	valid_0's multi_logloss: 1.1769e-05
# [3200]	valid_0's multi_logloss: 1.17657e-05
# [3400]	valid_0's multi_logloss: 1.17628e-05
# [3600]	valid_0's multi_logloss: 1.17602e-05
# [3800]	valid_0's multi_logloss: 1.17579e-05
# [4000]	valid_0's multi_logloss: 1.17558e-05
# [4200]	valid_0's multi_logloss: 1.17539e-05
# [4400]	valid_0's multi_logloss: 1.17522e-05
# [4600]	valid_0's multi_logloss: 1.17507e-05
# [4800]	valid_0's multi_logloss: 1.17492e-05
# [5000]	valid_0's multi_logloss: 1.17479e-05
# [200]	valid_0's multi_logloss: 0.000171844
# [400]	valid_0's multi_logloss: 0.000171496
# [600]	valid_0's multi_logloss: 0.000171411
# [800]	valid_0's multi_logloss: 0.000171372
# [1000]	valid_0's multi_logloss: 0.000171351
# [1200]	valid_0's multi_logloss: 0.000171337
# [1400]	valid_0's multi_logloss: 0.000171328
# [1600]	valid_0's multi_logloss: 0.000171321
# [1800]	valid_0's multi_logloss: 0.000171316
# [2000]	valid_0's multi_logloss: 0.000171312
# [2200]	valid_0's multi_logloss: 0.000171309
# [2400]	valid_0's multi_logloss: 0.000171306
# [2600]	valid_0's multi_logloss: 0.000171304
# [2800]	valid_0's multi_logloss: 0.000171302
# [3000]	valid_0's multi_logloss: 0.0001713
# [3200]	valid_0's multi_logloss: 0.000171299
# [3400]	valid_0's multi_logloss: 0.000171298
# [3600]	valid_0's multi_logloss: 0.000171296
# [3800]	valid_0's multi_logloss: 0.000171295
# [4000]	valid_0's multi_logloss: 0.000171295
# [4200]	valid_0's multi_logloss: 0.000171294
# [4400]	valid_0's multi_logloss: 0.000171293
# [4600]	valid_0's multi_logloss: 0.000171292
# [4800]	valid_0's multi_logloss: 0.000171292
# [5000]	valid_0's multi_logloss: 0.000171291
# [200]	valid_0's multi_logloss: 0.000286079
# [200]	valid_0's multi_logloss: 0.0128668
# [200]	valid_0's multi_logloss: 0.0252586

# %%
lgb_preds=0
for model in model_list:
    lgb_preds+=model.predict(df_new[feats])

# %%
labels=np.argmax(lgb_preds,axis=1)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.subplot(label="bla")
sns.scatterplot(df[feats], marker='o')
ax.set_title("Before clustering")
# Out:
# Text(0.5, 1.0, 'Before clustering')

# %%
df['Clusters'].dtype
# Out:
# dtype('int64')

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(df[feats], c=df["Clusters"], marker='o',cmap="rainbow")
ax.set_title("After Clustering")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 fig = plt.figure(figsize=(10,8))
# ----> 2 sns.scatterplot(df[feats], c=df["Clusters"], marker='o',cmap="rainbow")
#       3 ax.set_title("After Clustering")
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:464, in _ScatterPlotter.plot(self, ax, kws)
#     462 if self.legend:
#     463     attrs = {"hue": "color", "size": "s", "style": None}
# --> 464     self.add_legend_data(ax, _scatter_legend_artist, kws, attrs)
#     465     handles, _ = ax.get_legend_handles_labels()
#     466     if handles:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:1267, in VectorPlotter.add_legend_data(self, ax, func, common_kws, attrs, semantic_kws)
#    1265     if attr in kws:
#    1266         level_kws[attr] = kws[attr]
# -> 1267 artist = func(label=label, **{"color": ".2", **common_kws, **level_kws})
#    1268 if _version_predates(mpl, "3.5.0"):
#    1269     if isinstance(artist, mpl.lines.Line2D):
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\utils.py:880, in _scatter_legend_artist(**kws)
#     877     else:
#     878         line_kws["markeredgecolor"] = edgecolor
# --> 880 return mpl.lines.Line2D([], [], **line_kws)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1195, in Artist._update_props(self, props, errfmt)
#    1192             if not callable(func):
#    1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
# -> 1195             ret.append(func(v))
#    1196 if ret:
#    1197     self.pchanged()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:247, in define_aliases.<locals>.make_alias.<locals>.method(self, *args, **kwargs)
#     245 @functools.wraps(getattr(cls, name))
#     246 def method(self, *args, **kwargs):
# --> 247     return getattr(self, name)(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\lines.py:1061, in Line2D.set_color(self, color)
#    1053 def set_color(self, color):
#    1054     """
#    1055     Set the color of the line.
#    1056
#    (...)
#    1059     color : color
#    1060     """
# -> 1061     mcolors._check_color_like(color=color)
#    1062     self._color = color
#    1063     self.stale = True
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\colors.py:246, in _check_color_like(**kwargs)
#     244 for k, v in kwargs.items():
#     245     if not is_color_like(v):
# --> 246         raise ValueError(f"{v!r} is not a valid value for {k}")
#
# ValueError: 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 360    0
# 361    0
# 362    2
# 363    0
# 364    0
# Name: Clusters, Length: 365, dtype: int64 is not a valid value for color

# %%
pl = sns.countplot(x=np.argmax(lgb_preds,axis=1))
pl.set_title("Distribution Of The Clusters")
plt.show()

# %%
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df['Day'] = pd.to_datetime(df['Day'], format='%d/%m/%Y')
df.sort_values(by='Day', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
test_size = df[df['Day'].dt.month==12].shape[0]
test_size
# Out:
# 31

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'orange'
plt.rc('axes',edgecolor='white')
plt.plot(df['Day'][:-test_size], df['4'][:-test_size], color='black', lw=2)
plt.plot(df['Day'][-test_size:], df['4'][-test_size:], color='blue', lw=2)
plt.title('4', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('4', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
import plotly.express as px
fig = px.line(y=df['4'], x=df['Day'])
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Ngày",
                  yaxis_title="4",
                  title={'text': "Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(53,223,0,0.8)')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df['4'].values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
window_size = 15

# %%
train_data = df['4'][:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-window_size:i, 0])
    y_train.append(train_data[i, 0])

# %%
test_data = df['4'][-test_size-window_size:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-window_size:i, 0])
    y_test.append(test_data[i, 0])

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64)(input1)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=1)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 15, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,009 (74.25 KB)
#  Trainable params: 19,009 (74.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0549 - val_loss: 0.0220
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0303 - val_loss: 0.0161
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0347 - val_loss: 0.0154
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - val_loss: 0.0160
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0266 - val_loss: 0.0161
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0238 - val_loss: 0.0156
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0196 - val_loss: 0.0156
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0217 - val_loss: 0.0168
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0238 - val_loss: 0.0158
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - val_loss: 0.0161
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0261 - val_loss: 0.0184
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156 - val_loss: 0.0194
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0226 - val_loss: 0.0180
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0230 - val_loss: 0.0164
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201 - val_loss: 0.0168
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - val_loss: 0.0158
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0186 - val_loss: 0.0162
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0177 - val_loss: 0.0168
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145 - val_loss: 0.0176
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - val_loss: 0.0170
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - val_loss: 0.0165
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145 - val_loss: 0.0191
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0151 - val_loss: 0.0177
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0174
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - val_loss: 0.0177
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - val_loss: 0.0174
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - val_loss: 0.0177
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0176
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - val_loss: 0.0173
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - val_loss: 0.0185
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - val_loss: 0.0178
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - val_loss: 0.0178
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - val_loss: 0.0173
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - val_loss: 0.0182
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - val_loss: 0.0179
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - val_loss: 0.0190
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - val_loss: 0.0176
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107 - val_loss: 0.0182
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0190
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - val_loss: 0.0183
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - val_loss: 0.0187
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0188
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - val_loss: 0.0178
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - val_loss: 0.0180
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - val_loss: 0.0182
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - val_loss: 0.0184
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0111 - val_loss: 0.0199
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - val_loss: 0.0182
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099 - val_loss: 0.0182
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0187
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - val_loss: 0.0180
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - val_loss: 0.0179
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - val_loss: 0.0171
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0095 - val_loss: 0.0187
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0206
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - val_loss: 0.0179
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - val_loss: 0.0178
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 0.0185
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0189
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - val_loss: 0.0182
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0109 - val_loss: 0.0176
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - val_loss: 0.0170
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - val_loss: 0.0204
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - val_loss: 0.0170
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - val_loss: 0.0191
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104 - val_loss: 0.0175
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - val_loss: 0.0195
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - val_loss: 0.0169
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - val_loss: 0.0181
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - val_loss: 0.0169
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - val_loss: 0.0187
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - val_loss: 0.0169
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - val_loss: 0.0190
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - val_loss: 0.0181
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0173
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - val_loss: 0.0176
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - val_loss: 0.0196
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - val_loss: 0.0186
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0149 - val_loss: 0.0185
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0184
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0208
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0192
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0110 - val_loss: 0.0176
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - val_loss: 0.0185
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103 - val_loss: 0.0170
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - val_loss: 0.0221
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - val_loss: 0.0180
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103 - val_loss: 0.0183
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - val_loss: 0.0208
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0187
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - val_loss: 0.0190
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - val_loss: 0.0216
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - val_loss: 0.0186
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - val_loss: 0.0202
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - val_loss: 0.0189
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - val_loss: 0.0202
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - val_loss: 0.0194
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0115 - val_loss: 0.0177
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0212
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0203

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
from sklearn.metrics import mean_absolute_percentage_error,accuracy_score,r2_score
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1-MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.02014479599893093
# Test MAPE: 1.9647321501072474
# Test Accuracy: -0.9647321501072474

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'orange'
plt.rc('axes',edgecolor='white')
plt.plot(df['Day'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Day'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Day'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('4', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
